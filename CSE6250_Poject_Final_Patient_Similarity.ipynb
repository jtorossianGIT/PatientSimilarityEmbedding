# %%
#IMPORT LIBRARIES
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import re
import itertools
import json
import sys
import os
import time
import traceback
from lxml import etree
import json as json
from rdflib import Graph, URIRef, Namespace
#NEEDED BY PYKEEN
import scipy
import click
import more_itertools
import sklearn
import docdata
import pystow
import dataclasses_json
import click_default_group
import tabulate 
import torch
import optuna
import rexmex
import class_resolver
import requests
import tqdm
import more_click
import matplotlib
import seaborn
import time
from tqdm import tqdm


#RELATED TO PYKEEN
import tensorflow #as tf
import pykeen as pk
from pykeen.models import TransR, TransE
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline
from pykeen.models.predict import get_tail_prediction_df
from pykeen.models import predict 
import pykeen.models as pkmodels
from pykeen.training import SLCWATrainingLoop
from pykeen.evaluation import RankBasedEvaluator

from torch.optim import Adam
from typing import List

from matplotlib import pyplot as plt
import sklearn.model_selection as sk
from statistics import mean
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#HELPER FUNCTIONS


#UNIQUE PATIENT-MEDICAL CONCEPT TO BUILD GRAPH
def build_triplet_dataframe(df,head,relation,tail):
    triplet_df = df[[head, tail]].copy()
    triplet_df['RELATION'] = relation
    triplet_df = triplet_df.drop_duplicates()
    triplet_df = triplet_df.rename(columns={triplet_df.columns[0]: "Head",
                                            triplet_df.columns[1]: "Tail",
                                            triplet_df.columns[2]: "Relation"})
    triplet_df = triplet_df[["Head","Relation","Tail"]]
    #Convert to string so it can be accepted by pykeen's graph builder
    triplet_df["Head"] = triplet_df["Head"].astype(str)
    triplet_df["Tail"] = triplet_df["Tail"].astype(str)
    
      
    return triplet_df

# %% [markdown]
# ## A. EXPERIMENTAL SETTINGS
# ### 1) DATASETS
#
# #### Drugbank

# %%
#Adapted from: https://gist.github.com/rosherbal/56461421c69a8a7da775336c95fa62e0

class Drug:

    def __init__(self, features):

        self.id = features['id']
        self.name = features['name']
        self.synonyms = features['synm']
        self.kingdom = features['kgd']
        self.superclass = features['sclass']
        self.interaction = features['itrc']
        self.external_id = features['ext_id']
        self.pathways = features['pathways']
        self.target = []

    def getDrugfeatures(self):
        drug_dict = {"dg_id":self.id,
                    "dg_name":self.name,
                    "dg_synm":self.synonyms,
                    "dg_kingdom":self.kingdom,
                    "dg_superclass":self.superclass,
                    "dg_interactions":self.interaction,
                    "dg_ext_id":self.external_id,
                    "dg_pathways":self.pathways}
        return drug_dict

    def addTarget(self, feature_target):
        self.target.append(feature_target)

# Parameters and required variables #

dB_file = 'CSE6250_Project_Data/Drugbank.xml'
organism = 'Humans'

# Main script #

xtree = ET.parse(dB_file)
xroot = xtree.getroot()
drugs = list(xroot)

drug_targets = []
for i in tqdm(range(len(drugs))):
    drug = drugs[i]
    idDB = drug[0].text # Drug Bank ID

    for idx,feature in enumerate(drug):
        if 'name' in str(feature): # drug name
            drug_name = drug[idx].text

        if 'synonyms' in str(feature): # drug's synonyms
            drug_synm = ';'.join([synm.text \
                                    for synm in list(drug[idx])])

        if 'classification' in str(feature): #type of drug
            drug_class_kingdom = list(drug[idx])[2].text
            drug_class_superclass = list(drug[idx])[3].text

        if 'drug-interactions' in str(feature): #interaction other drugs
            drug_interaction = ';'.join([di[0].text
                                        for di in list(drug[idx])])

        if 'external-identifiers' in str(feature): #other drug's IDs
            aux = [ext_id[0].text + ":" + ext_id[1].text \
                                        for ext_id in list(drug[idx])]
            drug_external_id = ';'.join(aux)

        if 'pathways' in str(feature): #related pathways
            drug_pathway = ';'.join([pathway[1].text \
                                    for pathway in list(drug[idx])])

        if 'targets' in str(feature): #if polypeptide, drug's targets
            targets = list(drug[idx])

    # get all drug-related information in a dictionary
    drug_dict = {"id":idDB,
                "name":drug_name,
                "synm":drug_synm,
                "kgd":drug_class_kingdom,
                "sclass":drug_class_superclass,
                "itrc":drug_interaction,
                "ext_id":drug_external_id,
                "pathways":drug_pathway}
    drug = Drug(drug_dict)

    # get information of polypeptide targets
    if len(targets) > 0:
        for target in targets:
            idx_pep = None
            # get indexes
            for idx,feature in enumerate(target): # check features of targets
                if 'organism' in str(feature):
                    idx_org = idx
                if 'name' in str(feature):
                    idx_name = idx
                if 'actions' in str(feature):
                    idx_act = idx
                if 'polypeptide' in str(feature):
                    idx_pep = idx

            # Get information for polypeptide
            if target[idx_org].text == organism:

                target_name = target[idx_name].text

                actions = ';'.join([action.text
                                    for action in list(target[idx_act])])

                # Get information for polypeptide
                if idx_pep is not None: #if there is polypeptide's info...
                    for idx,feature in enumerate(target[idx_pep]):
                        if 'gene-name' in str(feature):
                            gene_name = target[idx_pep][idx].text
                        if 'cellular-location' in str(feature):
                            cell_loc = target[idx_pep][idx].text
                        if 'external-identifiers' in str(feature):
                            for ext_id in list(target[idx_pep][idx]):
                                if ext_id[0].text == "UniProtKB":
                                    uniprot = ext_id[1].text
                else:
                    gene_name = None
                    action = None
                    cell_loc = None
                    uniprot = None

                row = {
                        "dg_id":drug.id,
                        "dg_name":drug.name,
                        "dg_synm":drug.synonyms,
                        "dg_kingdom":drug.kingdom,
                        "dg_superclass":drug.superclass,
                        "dg_interactions":drug.interaction,
                        "dg_ext_id":drug.external_id,
                        "dg_pathways":drug.pathways,
                        "target_name":target_name,
                        "target_uniprot":uniprot,
                        "target_gene_name":gene_name,
                        "action":actions,
                        "cell_loc":cell_loc,
                        }

                drug_targets.append(row)


Drugbank_df = pd.DataFrame.from_dict(drug_targets, orient='columns')
# Out:
# 100%|███████████████████████████████████| 14594/14594 [00:05<00:00, 2489.66it/s]

# %%
#Clean up Drugbank dataframex
Drugbank_df = Drugbank_df[['dg_id','dg_name','dg_synm','dg_interactions']]
Drugbank_df = Drugbank_df.drop_duplicates()
Drugbank_df.head(5)
# Out:
#       dg_id              dg_name  \
# 0   DB00001            Lepirudin
# 1   DB00002            Cetuximab
# 9   DB00003         Dornase alfa
# 10  DB00004  Denileukin diftitox
# 13  DB00005           Etanercept
#
#                                               dg_synm  \
# 0   Hirudin variant-1;Lepirudin;Lepirudin recombinant
# 1                     Cetuximab;Cétuximab;Cetuximabum
# 9   Deoxyribonuclease (human clone 18-1 protein mo...
# 10  Denileukin;Denileukin diftitox;Interleukin-2/d...
# 13  Etanercept;etanercept-szzs;etanercept-ykro;Rec...
#
#                                       dg_interactions
# 0   DB06605;DB06695;DB01254;DB01609;DB01586;DB0212...
# 1   DB00255;DB00269;DB00286;DB00655;DB00783;DB0089...
# 9
# 10                    DB00012;DB00016;DB08894;DB09107
# 13  DB08879;DB00531;DB06643;DB00065;DB00008;DB0001...

# %%
print("Drugbank:",len(Drugbank_df['dg_id'].unique()))
# Out:
# Drugbank: 5927

# %% [markdown]
# #### ICD9-Ontology

# %%
#ICD9 ONTOLOGY
ICD9_Ontology = pd.read_csv('CSE6250_Project_Data/ICD9CM.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)

#Extract ICD9 CODE FROM COLUMNS
ICD9_Ontology['ICD9_CODE'] = ICD9_Ontology['Class ID'].str.extract(r'((?<=ICD9CM[/]).*$)', expand=True)
ICD9_Ontology['Parents_ID'] = ICD9_Ontology['Parents'].str.extract(r'((?<=ICD9CM[/]).*$)', expand=True)
ICD9_Ontology = ICD9_Ontology[['ICD9_CODE','Preferred Label','Parents_ID','ICE','ICN', 'Scope Statement']]
ICD9_Ontology = ICD9_Ontology.dropna(subset=['ICD9_CODE'])
ICD9_Ontology['ICD9_CODE'] = ICD9_Ontology.apply(lambda x: x['ICD9_CODE'].replace('.',''), axis=1)

# %%
ICD9_Ontology.head()
# Out:
#   ICD9_CODE                                    Preferred Label Parents_ID  \
# 0      8372                                Recession of tendon       83.7
# 1      9878  Toxic effect of other specified gases, fumes, ...        987
# 2      8023                                 Arthroscopy, wrist       80.2
# 3      3464                                 Menstrual migraine        346
# 4     65513  Chromosomal abnormality in fetus, affecting ma...      655.1
#
#                                                  ICE  ICN Scope Statement
# 0                                                NaN  NaN             NaN
# 1                          Phosgene; Polyester fumes  NaN             NaN
# 2                                                NaN  NaN             NaN
# 3  Menstrual headache; Menstrually related migrai...  NaN             NaN
# 4                                                NaN  NaN             NaN

# %% [markdown]
# #### MIMIC III Data

# %%
#LOAD DATA

#MIMIC III DATA
#Defines each SUBJECT_ID in the database, i.e. defines a single patient.
#Patients = pd.read_csv('CSE6250_Project_Data/PATIENTS.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)
#Define a patient’s hospital admission
Admissions = pd.read_csv('CSE6250_Project_Data/ADMISSIONS.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)
#Contains ICD diagnoses for patients, most notably ICD-9 diagnoses.
Diagnoses = pd.read_csv('CSE6250_Project_Data/DIAGNOSES_ICD.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)
#Contains medication related order entries, i.e. prescriptions.
Medication = pd.read_csv('CSE6250_Project_Data/PRESCRIPTIONS.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)
#Contains ICD procedures for patients, most notably ICD-9 procedures
Procedures_ICD  = pd.read_csv('CSE6250_Project_Data/PROCEDURES_ICD.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)
#Contains all notes for patients
#Note_Events = pd.read_csv('CSE6250_Project_Data/NOTEEVENTS.csv.gz', compression='gzip',on_bad_lines='skip',low_memory=False)

#Contains current procedural terminology (CPT) codes, which facilitate billing for procedures performed on patients.
#Procedures_CPT  = pd.read_csv('CSE6250_Project_Data/CPTEVENTS.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)
#Contains all laboratory measurements for a given patient, including out patient data.
#LAB_Events = pd.read_csv('CSE6250_Project_Data/LABEVENTS.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)

#DICTIONARIES
#High-level definitions for current procedural terminology (CPT) codes.
#D_CPT = pd.read_csv('CSE6250_Project_Data/D_CPT.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)
#Definition table for ICD diagnoses.
#D_ICD_Diagnoses = pd.read_csv('CSE6250_Project_Data/D_ICD_DIAGNOSES.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)
#Definition table for ICD procedures.
#D_ICD_Procedures = pd.read_csv('CSE6250_Project_Data/D_ICD_PROCEDURES.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)
#Definition table for all laboratory measurements.
#D_ICD_LabItems = pd.read_csv('CSE6250_Project_Data/D_LABITEMS.csv.gz', compression='gzip',error_bad_lines=False,low_memory=False)

#FORMAT AND CLEAN DATASETS
Diagnoses = Diagnoses[['SUBJECT_ID','HADM_ID','ICD9_CODE']]
Diagnoses = Diagnoses.drop_duplicates()
Diagnoses = Diagnoses[Diagnoses['ICD9_CODE'].notna()]


Medication = Medication[['SUBJECT_ID','HADM_ID','NDC','DRUG','DRUG_NAME_GENERIC']]
Medication = Medication.drop_duplicates()
Medication['NDC'] = Medication['NDC'].astype(str)
Medication = Medication[(Medication['NDC'].notna()) &(Medication['NDC']!= '0.0')]

Procedures_ICD = Procedures_ICD[['SUBJECT_ID','HADM_ID','ICD9_CODE']]
Procedures_ICD = Procedures_ICD.drop_duplicates()
Procedures_ICD = Procedures_ICD[Procedures_ICD['ICD9_CODE'].notna()]

# %%
#DISEASE DEFINITION
#Tuples for every disease in case we need to add/remove
atherosclerosis = ('440','4140','4143','4144','4370')
    
heart_failure = ('39891','40201','40211','40291','40401','40403','40411','40413','40491','40493','428')
    
kidney_failure = ('584','6393','6693')
    
intestinal_diseases = ('001','002','003','004','005','006','007','008','009',  '0222', '1590', '1230', '1234', 
                            '1277', '1278', '1279', '129','1763', '2713', '27703', '3064', '56081', '56089', '5609', 
                            '5643','56979', '5789', '5798', '5799', '538', '7514', '74761', '7131','7724', '7772','7776',
                            '9473', '9733', '9738', '9739', 'V1000','V1009', 'V453', 'V5350', 'V5359', 'V757','7934',
                            'E9433','E9438', 'E9439', '86380', 'V023', 'V444', 'V160', 'E8584','86389', '86390','86399')
    
liver_diseases = ('0063', '0953','1225', '1228', '1550', '1552','1977','2308', '2353', '20972', '2115', '570', 
                      '571','64670','64671','64673','7516','864','9641','99682','V427','V1007')
    
pneumonia = ('00322','0116','0382','0551','0730''11505', '11515', '11595','480','481','482','483','484','485',
                 '486','4870','48801', '48811', '48881','5163','5171', '7700','99731','99732','V1261')
    
septicemia = ('0031','0223','038','0545', '77181')
    
respiratory_failure = ('5185','5188','77084')
    
gastritis = ('535',)
    
diseases_ICD9_codes = atherosclerosis + heart_failure + kidney_failure + intestinal_diseases + liver_diseases + pneumonia + septicemia + respiratory_failure + gastritis

# %% [markdown]
# ### 2) MEDICAL KNOWLEDGE GRAPH CONSTRUCTION
#
# #### a: THE SELECTION OF PATIENTS

# %%
#TO LIMIT PATIENT AMOUNT FOR TESTS
#Admissions = Admissions[Admissions.SUBJECT_ID<=500]

# %%
#a: THE SELECTION OF PATIENTS

#Patient Cohort : Atherosclerosis, Heart Failure, Kidney Failure, Intestinal Diseases, Liver Diseases, 
#Pneumonia, Septicemia, Respiratory Failure, and Gastritis

Patient_Cohort = pd.merge(Admissions[['SUBJECT_ID','HADM_ID','ADMITTIME','DISCHTIME']],
                         Diagnoses[['SUBJECT_ID','HADM_ID','ICD9_CODE']],
                         how = "left",
                         left_on = ['SUBJECT_ID','HADM_ID'],
                         right_on = ['SUBJECT_ID','HADM_ID'])
Patient_Cohort['ADMITTIME'] = pd.to_datetime(Patient_Cohort['ADMITTIME']).dt.date
Patient_Cohort['DISCHTIME'] = pd.to_datetime(Patient_Cohort['DISCHTIME']).dt.date
Patient_Cohort = Patient_Cohort[Patient_Cohort['ICD9_CODE'].notna()]


#Get the SUBJECT_ID and HADM_ID for patients suffering one of the cohort deseases and filter the Patient_Cohort dataset
Diagnosis_Cohort = Diagnoses[(Diagnoses["ICD9_CODE"].notna()) & (Diagnoses['ICD9_CODE'].str.startswith(diseases_ICD9_codes))]
ICD9_Complete_List = set(Diagnosis_Cohort['ICD9_CODE'].unique())
Patient_Cohort = pd.merge(Patient_Cohort,
                         Diagnosis_Cohort[['SUBJECT_ID']],
                         how = 'inner',
                         left_on =['SUBJECT_ID'],
                         right_on = ['SUBJECT_ID'])



#(1) We remove the patients with missing data on admission date and discharge date
Patient_Cohort = Patient_Cohort.dropna(subset=['ADMITTIME','DISCHTIME'])

#(2) We keep the patients which consist of at least three ICD-9 codes
#Create dataset copy with ICD9_Code grouped by visit
Grouped_ICD9_By_Visit = pd.DataFrame(Patient_Cohort.groupby(['SUBJECT_ID'])['ICD9_CODE'].apply(set)).reset_index()
Grouped_ICD9_By_Visit['ICD9_Count'] = Grouped_ICD9_By_Visit.apply(lambda x: len(x['ICD9_CODE']), axis=1)
Grouped_ICD9_By_Visit = Grouped_ICD9_By_Visit[Grouped_ICD9_By_Visit['ICD9_Count']>=3]

Patient_Cohort = pd.merge(Patient_Cohort,
                         Grouped_ICD9_By_Visit[['SUBJECT_ID']],
                         how = 'inner',
                         left_on = ['SUBJECT_ID'],
                         right_on = ['SUBJECT_ID'])

#(3) We remove the patients which have the discharge date after 2200/1/1
Patient_Cohort = Patient_Cohort[(Patient_Cohort['DISCHTIME'].astype(str) <= '2200-1-1')]


#COMENTED BECAUSE THE PATIENT COUNT GOT TOO LOW
#(4) we remove the patients who suffer from more than one disease in the cohort list.
# Multiple_Cohort_Desease = pd.DataFrame(Patient_Cohort.groupby(['SUBJECT_ID'])['ICD9_CODE'].apply(set)).reset_index()
# Multiple_Cohort_Desease['Disease_Set'] = Multiple_Cohort_Desease.apply(lambda x: len(x['ICD9_CODE'].intersection(ICD9_Complete_List)), axis=1)
# Unique_Cohort_Disease = Multiple_Cohort_Desease[Multiple_Cohort_Desease['Disease_Set'] ==1]

# Patient_Cohort = pd.merge(Patient_Cohort,
#                            Unique_Cohort_Disease[['SUBJECT_ID']],
#                            how = 'inner',
#                            left_on = ['SUBJECT_ID'],
#                            right_on = ['SUBJECT_ID'])

# %% [markdown]
# #### b: THE SELECTION OF MEDICAL CONCEPTS

# %%
#b: THE SELECTION OF MEDICAL CONCEPTS
Patient_Cohort.head()

#Reduce Patient_Cohort dataset
Patient_Cohort = Patient_Cohort[['SUBJECT_ID','ICD9_CODE']]
Patient_Cohort = Patient_Cohort.drop_duplicates()

#MEDICATION
#Reduce Medication_cohort dataset
Medication_Cohort = Medication[['SUBJECT_ID','DRUG','NDC']]
Medication_Cohort = Medication_Cohort.drop_duplicates()

Medication_Cohort = pd.merge(Medication_Cohort,
                             Patient_Cohort[['SUBJECT_ID']],
                              how = 'inner',
                              left_on = ['SUBJECT_ID'],
                              right_on = ['SUBJECT_ID'] )

Medication_Cohort = Medication_Cohort.drop_duplicates()

#PROCEDURES
Procedures_Cohort = Procedures_ICD[['SUBJECT_ID','ICD9_CODE']]
Procedures_Cohort = Procedures_Cohort.drop_duplicates()

Procedures_Cohort = pd.merge(Procedures_Cohort,
                            Patient_Cohort[['SUBJECT_ID']],
                             how = 'inner',
                             left_on = ['SUBJECT_ID'],
                             right_on = ['SUBJECT_ID'] )

Procedures_Cohort = Procedures_Cohort.drop_duplicates()

#Remove medical concepts which appear less than five patients to avoid biases and noise
#DIAGNOSES
ICD9_CODE_Patient_Count = Patient_Cohort.groupby(["ICD9_CODE"], as_index= False)["SUBJECT_ID"].count()
ICD9_CODE_Patient_Count = ICD9_CODE_Patient_Count[ICD9_CODE_Patient_Count['SUBJECT_ID']>=5]

Patient_Cohort = pd.merge(Patient_Cohort,
                          ICD9_CODE_Patient_Count[['ICD9_CODE']],
                           how = 'inner',
                           left_on = 'ICD9_CODE',
                           right_on = 'ICD9_CODE')


#MEDICATION
Medication_Patient_Count = Medication_Cohort.groupby(["NDC"], as_index= False)["SUBJECT_ID"].count()
Medication_Patient_Count = Medication_Patient_Count[Medication_Patient_Count['SUBJECT_ID']>=5]

Medication_Cohort = pd.merge(Medication_Cohort,
                        Medication_Patient_Count[['NDC']],
                         how = 'inner',
                         left_on = 'NDC',
                         right_on = 'NDC')

#PROCEDURES
Procedures_Patient_Count = Procedures_Cohort.groupby(["ICD9_CODE"], as_index= False)["SUBJECT_ID"].count()
Procedures_Patient_Count = Procedures_Patient_Count[Procedures_Patient_Count['SUBJECT_ID']>=5]

Procedures_Cohort = pd.merge(Procedures_Cohort,
                        Procedures_Patient_Count[['ICD9_CODE']],
                         how = 'inner',
                         left_on = 'ICD9_CODE',
                         right_on = 'ICD9_CODE')

# %%
print("Final Patient Cohort Dataset also used for Diagnosis Cohort:")
print("Patient_Cohort:",len(Patient_Cohort['SUBJECT_ID'].unique()))
#Diagnosis Count
print("Diagnosis Cohort:",len(Patient_Cohort['ICD9_CODE'].unique()))

#Medication Count
print("Medication_Cohort:",len(Medication_Cohort['DRUG'].unique()))

#Procedure Count
print("Procedure_Cohort:",len(Procedures_Cohort['ICD9_CODE'].unique()))
# Out:
# Final Patient Cohort Dataset also used for Diagnosis Cohort:
# Patient_Cohort: 28592
# Diagnosis Cohort: 3180
# Medication_Cohort: 3585
# Procedure_Cohort: 953

# %%
#B. MEDICAL KNOWLEDGE TRIPLETS
#CREATE DATAFRAME OF TRIPLETS IN THE FORM [(4, 'diagnosed', '2763'),(4, 'performed', 3893),(4, 'prescribed', 'Heparin')...]

Patient_Diagnoses_Triplets = build_triplet_dataframe(Patient_Cohort,'SUBJECT_ID','diagnosed','ICD9_CODE')
Patient_Medications_Triplets = build_triplet_dataframe(Medication_Cohort,'SUBJECT_ID','prescribed','DRUG')
Patient_Procedures_Triplets = build_triplet_dataframe(Procedures_Cohort,'SUBJECT_ID','performed','ICD9_CODE')

Medical_Knowledge_Triplets_df = pd.concat([Patient_Diagnoses_Triplets,
                                            Patient_Medications_Triplets,
                                            Patient_Procedures_Triplets],ignore_index=True)
Medical_Knowledge_Triplets_df = Medical_Knowledge_Triplets_df.sort_values(by=['Head'])

Medical_Knowledge_Triplets_df.head(5)

Medical_Knowledge_Triplets_List = [tuple(r) for r in Medical_Knowledge_Triplets_df.to_numpy().tolist()]

# %%
Medical_Knowledge_Triplets_df.head(5)
# Out:
#          Head    Relation                Tail
# 476459   1000  prescribed      Vancomycin HCl
# 342817   1000   diagnosed                5789
# 1470362  1000  prescribed  D5W (GLASS BOTTLE)
# 540740   1000  prescribed        Pantoprazole
# 344206   1000   diagnosed                0380

# %%
#Count Relationships
print("Patient - Diagnoses:",len(Medical_Knowledge_Triplets_df[Medical_Knowledge_Triplets_df['Relation'] == 'diagnosed']))

print("Patient - Medication:",len(Medical_Knowledge_Triplets_df[Medical_Knowledge_Triplets_df['Relation'] == 'prescribed']))

print("Patient - Procedures:",len(Medical_Knowledge_Triplets_df[Medical_Knowledge_Triplets_df['Relation'] == 'performed']))
# Out:
# Patient - Diagnoses: 450915
# Patient - Medication: 1108080
# Patient - Procedures: 167829

# %%
#CREATE MEDICAL ENTITY TRIPLETS
#Purpose: Stack the Medical Entity Triplets dataframe on top of the medical entity triplets to train the embedding model

#DRUGS: Using MIMIC III Drug name['DRUG'] link as 'SameAs' to Dugbank id 'drugbank_id'
#Example: (Insuline, SameAs, DB00030)

# %% [markdown]
# ### Testing and Training Medical Knowledge Graph Embedding Models

# %%
#Convert data to labeled triplets and split into training, testing and validation sets
#To feed the models

tf = TriplesFactory.from_labeled_triples(Medical_Knowledge_Triplets_df[['Head','Relation','Tail']].values)
training, testing, validation = tf.split([.8, .1, .1])

#GET labels and IDS
labels = [x for x in list(tf.entity_id_to_label.values()) if '^^' not in x]
ids = torch.as_tensor(tf.entities_to_ids(labels))
# Out:
# using automatically assigned random_state=1799667425

# %% [markdown]
# ### MODEL 1

# %%
#  MEDICAL KNOWLEDGE GRAPH EMBEDDINGS USING PYKEEN'S TRANSR METHOD 1 USING PIPELINE

#Train a knowledge graph embedding model

result = pipeline(
     training=training,
     testing=testing,
     validation=validation,
     model='TransR',
     stopper='early',
     epochs=10,
     dimensions=512,
     random_seed=420)
# Out:
# No cuda devices were available. The model runs on CPU
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:369: UserWarning: Directly use Embedding.max_id instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.max_id instead of num_embeddings.")
# Training epochs on cpu:   0%|                         | 0/10 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|                      | 0/5397 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|              | 1/5397 [00:00<10:10,  8.84batch/s]
# Training batches on cpu:   0%|              | 4/5397 [00:00<04:42, 19.11batch/s]
# Training batches on cpu:   0%|              | 7/5397 [00:00<03:47, 23.73batch/s]
# Training batches on cpu:   0%|             | 11/5397 [00:00<03:21, 26.78batch/s]
# Training batches on cpu:   0%|             | 14/5397 [00:00<03:14, 27.74batch/s]
# Training batches on cpu:   0%|             | 17/5397 [00:00<03:11, 28.13batch/s]
# Training batches on cpu:   0%|             | 20/5397 [00:00<03:13, 27.82batch/s]
# Training batches on cpu:   0%|             | 23/5397 [00:00<03:11, 28.02batch/s]
# Training batches on cpu:   0%|             | 26/5397 [00:00<03:07, 28.59batch/s]
# Training batches on cpu:   1%|             | 29/5397 [00:01<03:08, 28.50batch/s]
# Training batches on cpu:   1%|             | 32/5397 [00:01<03:11, 28.05batch/s]
# Training batches on cpu:   1%|             | 35/5397 [00:01<03:09, 28.29batch/s]
# Training batches on cpu:   1%|             | 39/5397 [00:01<03:04, 29.10batch/s]
# Training batches on cpu:   1%|             | 42/5397 [00:01<03:04, 28.98batch/s]
# Training batches on cpu:   1%|             | 46/5397 [00:01<03:01, 29.50batch/s]
# Training batches on cpu:   1%|             | 49/5397 [00:01<03:04, 29.03batch/s]
# Training batches on cpu:   1%|▏            | 52/5397 [00:01<03:05, 28.81batch/s]
# Training batches on cpu:   1%|▏            | 55/5397 [00:01<03:03, 29.11batch/s]
# Training batches on cpu:   1%|▏            | 58/5397 [00:02<03:06, 28.59batch/s]
# Training batches on cpu:   1%|▏            | 61/5397 [00:02<03:07, 28.51batch/s]
# Training batches on cpu:   1%|▏            | 64/5397 [00:02<03:06, 28.53batch/s]
# Training batches on cpu:   1%|▏            | 67/5397 [00:02<03:07, 28.44batch/s]
# Training batches on cpu:   1%|▏            | 70/5397 [00:02<03:09, 28.17batch/s]
# Training batches on cpu:   1%|▏            | 73/5397 [00:02<03:10, 27.90batch/s]
# Training batches on cpu:   1%|▏            | 76/5397 [00:02<03:07, 28.40batch/s]
# Training batches on cpu:   1%|▏            | 80/5397 [00:02<03:01, 29.24batch/s]
# Training batches on cpu:   2%|▏            | 83/5397 [00:02<03:01, 29.27batch/s]
# Training batches on cpu:   2%|▏            | 86/5397 [00:03<03:00, 29.42batch/s]
# Training batches on cpu:   2%|▏            | 90/5397 [00:03<02:57, 29.84batch/s]
# Training batches on cpu:   2%|▏            | 94/5397 [00:03<02:55, 30.19batch/s]
# Training batches on cpu:   2%|▏            | 98/5397 [00:03<02:56, 30.08batch/s]
# Training batches on cpu:   2%|▏           | 102/5397 [00:03<02:58, 29.67batch/s]
# Training batches on cpu:   2%|▏           | 105/5397 [00:03<02:58, 29.65batch/s]
# Training batches on cpu:   2%|▏           | 108/5397 [00:03<03:01, 29.21batch/s]
# Training batches on cpu:   2%|▏           | 111/5397 [00:03<03:01, 29.09batch/s]
# Training batches on cpu:   2%|▎           | 114/5397 [00:04<03:02, 28.93batch/s]
# Training batches on cpu:   2%|▎           | 118/5397 [00:04<02:58, 29.58batch/s]
# Training batches on cpu:   2%|▎           | 121/5397 [00:04<03:00, 29.29batch/s]
# Training batches on cpu:   2%|▎           | 125/5397 [00:04<02:56, 29.80batch/s]
# Training batches on cpu:   2%|▎           | 128/5397 [00:04<02:57, 29.72batch/s]
# Training batches on cpu:   2%|▎           | 131/5397 [00:04<02:58, 29.58batch/s]
# Training batches on cpu:   2%|▎           | 134/5397 [00:04<02:57, 29.66batch/s]
# Training batches on cpu:   3%|▎           | 137/5397 [00:04<02:59, 29.29batch/s]
# Training batches on cpu:   3%|▎           | 140/5397 [00:04<03:00, 29.12batch/s]
# Training batches on cpu:   3%|▎           | 143/5397 [00:04<03:01, 28.88batch/s]
# Training batches on cpu:   3%|▎           | 146/5397 [00:05<03:02, 28.73batch/s]
# Training batches on cpu:   3%|▎           | 149/5397 [00:05<03:02, 28.83batch/s]
# Training batches on cpu:   3%|▎           | 152/5397 [00:05<03:03, 28.64batch/s]
# Training batches on cpu:   3%|▎           | 155/5397 [00:05<03:01, 28.88batch/s]
# Training batches on cpu:   3%|▎           | 158/5397 [00:05<02:59, 29.16batch/s]
# Training batches on cpu:   3%|▎           | 162/5397 [00:05<02:56, 29.62batch/s]
# Training batches on cpu:   3%|▎           | 166/5397 [00:05<02:54, 30.06batch/s]
# Training batches on cpu:   3%|▍           | 170/5397 [00:05<02:51, 30.45batch/s]
# Training batches on cpu:   3%|▍           | 174/5397 [00:06<02:52, 30.30batch/s]
# Training batches on cpu:   3%|▍           | 178/5397 [00:06<02:53, 30.03batch/s]
# Training batches on cpu:   3%|▍           | 182/5397 [00:06<02:56, 29.51batch/s]
# Training batches on cpu:   3%|▍           | 185/5397 [00:06<02:55, 29.62batch/s]
# Training batches on cpu:   3%|▍           | 188/5397 [00:06<02:57, 29.32batch/s]
# Training batches on cpu:   4%|▍           | 191/5397 [00:06<02:57, 29.35batch/s]
# Training batches on cpu:   4%|▍           | 194/5397 [00:06<02:57, 29.30batch/s]
# Training batches on cpu:   4%|▍           | 197/5397 [00:06<02:58, 29.06batch/s]
# Training batches on cpu:   4%|▍           | 201/5397 [00:06<02:55, 29.65batch/s]
# Training batches on cpu:   4%|▍           | 204/5397 [00:07<02:56, 29.38batch/s]
# Training batches on cpu:   4%|▍           | 207/5397 [00:07<02:57, 29.21batch/s]
# Training batches on cpu:   4%|▍           | 210/5397 [00:07<02:59, 28.97batch/s]
# Training batches on cpu:   4%|▍           | 213/5397 [00:07<02:57, 29.22batch/s]
# Training batches on cpu:   4%|▍           | 216/5397 [00:07<03:03, 28.17batch/s]
# Training batches on cpu:   4%|▍           | 220/5397 [00:07<02:58, 29.02batch/s]
# Training batches on cpu:   4%|▍           | 223/5397 [00:07<02:58, 28.99batch/s]
# Training batches on cpu:   4%|▌           | 226/5397 [00:07<02:59, 28.84batch/s]
# Training batches on cpu:   4%|▌           | 230/5397 [00:07<02:54, 29.56batch/s]
# Training batches on cpu:   4%|▌           | 233/5397 [00:08<02:55, 29.43batch/s]
# Training batches on cpu:   4%|▌           | 236/5397 [00:08<02:58, 28.94batch/s]
# Training batches on cpu:   4%|▌           | 239/5397 [00:08<02:58, 28.95batch/s]
# Training batches on cpu:   4%|▌           | 242/5397 [00:08<02:56, 29.24batch/s]
# Training batches on cpu:   5%|▌           | 246/5397 [00:08<02:53, 29.71batch/s]
# Training batches on cpu:   5%|▌           | 249/5397 [00:08<02:53, 29.66batch/s]
# Training batches on cpu:   5%|▌           | 253/5397 [00:08<02:51, 30.05batch/s]
# Training batches on cpu:   5%|▌           | 256/5397 [00:08<02:52, 29.81batch/s]
# Training batches on cpu:   5%|▌           | 260/5397 [00:08<02:50, 30.14batch/s]
# Training batches on cpu:   5%|▌           | 264/5397 [00:09<02:50, 30.16batch/s]
# Training batches on cpu:   5%|▌           | 268/5397 [00:09<02:51, 29.85batch/s]
# Training batches on cpu:   5%|▌           | 271/5397 [00:09<02:54, 29.32batch/s]
# Training batches on cpu:   5%|▌           | 275/5397 [00:09<02:52, 29.68batch/s]
# Training batches on cpu:   5%|▌           | 278/5397 [00:09<02:54, 29.39batch/s]
# Training batches on cpu:   5%|▌           | 281/5397 [00:09<02:56, 29.02batch/s]
# Training batches on cpu:   5%|▋           | 284/5397 [00:09<02:56, 29.04batch/s]
# Training batches on cpu:   5%|▋           | 287/5397 [00:10<04:46, 17.81batch/s]
# Training batches on cpu:   5%|▋           | 290/5397 [00:10<05:47, 14.68batch/s]
# Training batches on cpu:   5%|▋           | 292/5397 [00:10<06:14, 13.61batch/s]
# Training batches on cpu:   5%|▋           | 295/5397 [00:10<05:17, 16.05batch/s]
# Training batches on cpu:   6%|▋           | 298/5397 [00:10<04:32, 18.71batch/s]
# Training batches on cpu:   6%|▋           | 301/5397 [00:10<04:02, 21.02batch/s]
# Training batches on cpu:   6%|▋           | 304/5397 [00:11<03:41, 23.01batch/s]
# Training batches on cpu:   6%|▋           | 307/5397 [00:11<03:27, 24.57batch/s]
# Training batches on cpu:   6%|▋           | 310/5397 [00:11<03:16, 25.87batch/s]
# Training batches on cpu:   6%|▋           | 313/5397 [00:11<03:08, 26.92batch/s]
# Training batches on cpu:   6%|▋           | 317/5397 [00:11<02:58, 28.43batch/s]
# Training batches on cpu:   6%|▋           | 321/5397 [00:11<02:54, 29.13batch/s]
# Training batches on cpu:   6%|▋           | 325/5397 [00:11<02:50, 29.68batch/s]
# Training batches on cpu:   6%|▋           | 329/5397 [00:11<02:47, 30.19batch/s]
# Training batches on cpu:   6%|▋           | 333/5397 [00:11<02:47, 30.28batch/s]
# Training batches on cpu:   6%|▋           | 337/5397 [00:12<02:47, 30.15batch/s]
# Training batches on cpu:   6%|▊           | 341/5397 [00:12<02:47, 30.27batch/s]
# Training batches on cpu:   6%|▊           | 345/5397 [00:12<02:46, 30.39batch/s]
# Training batches on cpu:   6%|▊           | 349/5397 [00:12<02:47, 30.15batch/s]
# Training batches on cpu:   7%|▊           | 353/5397 [00:12<02:47, 30.11batch/s]
# Training batches on cpu:   7%|▊           | 357/5397 [00:12<02:45, 30.38batch/s]
# Training batches on cpu:   7%|▊           | 361/5397 [00:12<02:49, 29.65batch/s]
# Training batches on cpu:   7%|▊           | 365/5397 [00:13<02:46, 30.14batch/s]
# Training batches on cpu:   7%|▊           | 369/5397 [00:13<02:47, 30.01batch/s]
# Training batches on cpu:   7%|▊           | 373/5397 [00:13<02:46, 30.16batch/s]
# Training batches on cpu:   7%|▊           | 377/5397 [00:13<02:46, 30.07batch/s]
# Training batches on cpu:   7%|▊           | 381/5397 [00:13<02:47, 29.98batch/s]
# Training batches on cpu:   7%|▊           | 385/5397 [00:13<02:46, 30.07batch/s]
# Training batches on cpu:   7%|▊           | 389/5397 [00:13<02:46, 29.99batch/s]
# Training batches on cpu:   7%|▊           | 393/5397 [00:13<02:47, 29.83batch/s]
# Training batches on cpu:   7%|▉           | 396/5397 [00:14<02:49, 29.45batch/s]
# Training batches on cpu:   7%|▉           | 400/5397 [00:14<02:47, 29.90batch/s]
# Training batches on cpu:   7%|▉           | 404/5397 [00:14<02:45, 30.24batch/s]
# Training batches on cpu:   8%|▉           | 408/5397 [00:14<02:44, 30.37batch/s]
# Training batches on cpu:   8%|▉           | 412/5397 [00:14<02:45, 30.16batch/s]
# Training batches on cpu:   8%|▉           | 416/5397 [00:14<02:49, 29.47batch/s]
# Training batches on cpu:   8%|▉           | 419/5397 [00:14<02:48, 29.52batch/s]
# Training batches on cpu:   8%|▉           | 422/5397 [00:14<02:48, 29.46batch/s]
# Training batches on cpu:   8%|▉           | 426/5397 [00:15<02:45, 29.95batch/s]
# Training batches on cpu:   8%|▉           | 430/5397 [00:15<02:45, 29.94batch/s]
# Training batches on cpu:   8%|▉           | 434/5397 [00:15<02:44, 30.11batch/s]
# Training batches on cpu:   8%|▉           | 438/5397 [00:15<02:42, 30.43batch/s]
# Training batches on cpu:   8%|▉           | 442/5397 [00:15<02:42, 30.46batch/s]
# Training batches on cpu:   8%|▉           | 446/5397 [00:15<02:41, 30.57batch/s]
# Training batches on cpu:   8%|█           | 450/5397 [00:15<02:41, 30.57batch/s]
# Training batches on cpu:   8%|█           | 454/5397 [00:15<02:40, 30.84batch/s]
# Training batches on cpu:   8%|█           | 458/5397 [00:16<02:40, 30.78batch/s]
# Training batches on cpu:   9%|█           | 462/5397 [00:16<02:40, 30.67batch/s]
# Training batches on cpu:   9%|█           | 466/5397 [00:16<02:42, 30.36batch/s]
# Training batches on cpu:   9%|█           | 470/5397 [00:16<02:47, 29.46batch/s]
# Training batches on cpu:   9%|█           | 473/5397 [00:16<02:53, 28.40batch/s]
# Training batches on cpu:   9%|█           | 476/5397 [00:16<02:56, 27.86batch/s]
# Training batches on cpu:   9%|█           | 479/5397 [00:16<02:56, 27.85batch/s]
# Training batches on cpu:   9%|█           | 483/5397 [00:17<02:50, 28.77batch/s]
# Training batches on cpu:   9%|█           | 486/5397 [00:17<02:49, 29.01batch/s]
# Training batches on cpu:   9%|█           | 489/5397 [00:17<02:47, 29.27batch/s]
# Training batches on cpu:   9%|█           | 492/5397 [00:17<02:46, 29.38batch/s]
# Training batches on cpu:   9%|█           | 496/5397 [00:17<02:43, 30.00batch/s]
# Training batches on cpu:   9%|█           | 500/5397 [00:17<02:41, 30.39batch/s]
# Training batches on cpu:   9%|█           | 504/5397 [00:17<02:41, 30.26batch/s]
# Training batches on cpu:   9%|█▏          | 508/5397 [00:17<02:42, 30.03batch/s]
# Training batches on cpu:   9%|█▏          | 512/5397 [00:17<02:40, 30.39batch/s]
# Training batches on cpu:  10%|█▏          | 516/5397 [00:18<02:41, 30.20batch/s]
# Training batches on cpu:  10%|█▏          | 520/5397 [00:18<02:41, 30.17batch/s]
# Training batches on cpu:  10%|█▏          | 524/5397 [00:18<02:39, 30.46batch/s]
# Training batches on cpu:  10%|█▏          | 528/5397 [00:18<02:38, 30.67batch/s]
# Training batches on cpu:  10%|█▏          | 532/5397 [00:18<02:37, 30.89batch/s]
# Training batches on cpu:  10%|█▏          | 536/5397 [00:18<02:36, 31.02batch/s]
# Training batches on cpu:  10%|█▏          | 540/5397 [00:18<02:36, 31.07batch/s]
# Training batches on cpu:  10%|█▏          | 544/5397 [00:18<02:36, 31.11batch/s]
# Training batches on cpu:  10%|█▏          | 548/5397 [00:19<02:37, 30.86batch/s]
# Training batches on cpu:  10%|█▏          | 552/5397 [00:19<02:38, 30.66batch/s]
# Training batches on cpu:  10%|█▏          | 556/5397 [00:19<02:37, 30.75batch/s]
# Training batches on cpu:  10%|█▏          | 560/5397 [00:19<02:39, 30.41batch/s]
# Training batches on cpu:  10%|█▎          | 564/5397 [00:19<02:39, 30.25batch/s]
# Training batches on cpu:  11%|█▎          | 568/5397 [00:19<02:38, 30.42batch/s]
# Training batches on cpu:  11%|█▎          | 572/5397 [00:19<02:37, 30.60batch/s]
# Training batches on cpu:  11%|█▎          | 576/5397 [00:20<02:36, 30.76batch/s]
# Training batches on cpu:  11%|█▎          | 580/5397 [00:20<02:37, 30.62batch/s]
# Training batches on cpu:  11%|█▎          | 584/5397 [00:20<02:36, 30.82batch/s]
# Training batches on cpu:  11%|█▎          | 588/5397 [00:20<02:36, 30.77batch/s]
# Training batches on cpu:  11%|█▎          | 592/5397 [00:20<02:35, 30.86batch/s]
# Training batches on cpu:  11%|█▎          | 596/5397 [00:20<02:36, 30.67batch/s]
# Training batches on cpu:  11%|█▎          | 600/5397 [00:20<02:36, 30.74batch/s]
# Training batches on cpu:  11%|█▎          | 604/5397 [00:20<02:37, 30.46batch/s]
# Training batches on cpu:  11%|█▎          | 608/5397 [00:21<02:36, 30.52batch/s]
# Training batches on cpu:  11%|█▎          | 612/5397 [00:21<02:41, 29.69batch/s]
# Training batches on cpu:  11%|█▎          | 616/5397 [00:21<02:38, 30.18batch/s]
# Training batches on cpu:  11%|█▍          | 620/5397 [00:21<02:37, 30.41batch/s]
# Training batches on cpu:  12%|█▍          | 624/5397 [00:21<02:36, 30.48batch/s]
# Training batches on cpu:  12%|█▍          | 628/5397 [00:21<02:36, 30.39batch/s]
# Training batches on cpu:  12%|█▍          | 632/5397 [00:21<02:35, 30.56batch/s]
# Training batches on cpu:  12%|█▍          | 636/5397 [00:22<02:35, 30.56batch/s]
# Training batches on cpu:  12%|█▍          | 640/5397 [00:22<02:35, 30.56batch/s]
# Training batches on cpu:  12%|█▍          | 644/5397 [00:22<02:36, 30.45batch/s]
# Training batches on cpu:  12%|█▍          | 648/5397 [00:22<02:37, 30.22batch/s]
# Training batches on cpu:  12%|█▍          | 652/5397 [00:22<02:36, 30.38batch/s]
# Training batches on cpu:  12%|█▍          | 656/5397 [00:22<02:34, 30.64batch/s]
# Training batches on cpu:  12%|█▍          | 660/5397 [00:22<02:34, 30.73batch/s]
# Training batches on cpu:  12%|█▍          | 664/5397 [00:22<02:33, 30.80batch/s]
# Training batches on cpu:  12%|█▍          | 668/5397 [00:23<02:32, 30.94batch/s]
# Training batches on cpu:  12%|█▍          | 672/5397 [00:23<02:31, 31.11batch/s]
# Training batches on cpu:  13%|█▌          | 676/5397 [00:23<02:32, 30.91batch/s]
# Training batches on cpu:  13%|█▌          | 680/5397 [00:23<02:33, 30.79batch/s]
# Training batches on cpu:  13%|█▌          | 684/5397 [00:23<02:32, 30.86batch/s]
# Training batches on cpu:  13%|█▌          | 688/5397 [00:23<02:33, 30.69batch/s]
# Training batches on cpu:  13%|█▌          | 692/5397 [00:23<02:34, 30.52batch/s]
# Training batches on cpu:  13%|█▌          | 696/5397 [00:23<02:32, 30.73batch/s]
# Training batches on cpu:  13%|█▌          | 700/5397 [00:24<02:31, 31.09batch/s]
# Training batches on cpu:  13%|█▌          | 704/5397 [00:24<02:30, 31.15batch/s]
# Training batches on cpu:  13%|█▌          | 708/5397 [00:24<02:30, 31.21batch/s]
# Training batches on cpu:  13%|█▌          | 712/5397 [00:24<02:29, 31.31batch/s]
# Training batches on cpu:  13%|█▌          | 716/5397 [00:24<02:31, 30.83batch/s]
# Training batches on cpu:  13%|█▌          | 720/5397 [00:24<02:34, 30.35batch/s]
# Training batches on cpu:  13%|█▌          | 724/5397 [00:25<03:46, 20.59batch/s]
# Training batches on cpu:  13%|█▌          | 727/5397 [00:25<04:27, 17.49batch/s]
# Training batches on cpu:  14%|█▌          | 730/5397 [00:25<04:01, 19.34batch/s]
# Training batches on cpu:  14%|█▋          | 733/5397 [00:25<04:14, 18.33batch/s]
# Training batches on cpu:  14%|█▋          | 736/5397 [00:25<03:50, 20.19batch/s]
# Training batches on cpu:  14%|█▋          | 740/5397 [00:25<03:22, 23.01batch/s]
# Training batches on cpu:  14%|█▋          | 744/5397 [00:25<03:04, 25.17batch/s]
# Training batches on cpu:  14%|█▋          | 748/5397 [00:26<02:53, 26.86batch/s]
# Training batches on cpu:  14%|█▋          | 751/5397 [00:26<02:48, 27.54batch/s]
# Training batches on cpu:  14%|█▋          | 754/5397 [00:26<02:46, 27.94batch/s]
# Training batches on cpu:  14%|█▋          | 757/5397 [00:26<02:43, 28.34batch/s]
# Training batches on cpu:  14%|█▋          | 761/5397 [00:26<02:39, 29.08batch/s]
# Training batches on cpu:  14%|█▋          | 765/5397 [00:26<02:36, 29.61batch/s]
# Training batches on cpu:  14%|█▋          | 769/5397 [00:26<02:34, 29.96batch/s]
# Training batches on cpu:  14%|█▋          | 773/5397 [00:26<02:34, 29.96batch/s]
# Training batches on cpu:  14%|█▋          | 777/5397 [00:27<02:33, 30.16batch/s]
# Training batches on cpu:  14%|█▋          | 781/5397 [00:27<02:32, 30.28batch/s]
# Training batches on cpu:  15%|█▋          | 785/5397 [00:27<02:30, 30.54batch/s]
# Training batches on cpu:  15%|█▊          | 789/5397 [00:27<02:31, 30.47batch/s]
# Training batches on cpu:  15%|█▊          | 793/5397 [00:27<02:31, 30.30batch/s]
# Training batches on cpu:  15%|█▊          | 797/5397 [00:27<02:32, 30.24batch/s]
# Training batches on cpu:  15%|█▊          | 801/5397 [00:27<02:30, 30.56batch/s]
# Training batches on cpu:  15%|█▊          | 805/5397 [00:27<02:30, 30.53batch/s]
# Training batches on cpu:  15%|█▊          | 809/5397 [00:28<02:30, 30.51batch/s]
# Training batches on cpu:  15%|█▊          | 813/5397 [00:28<02:28, 30.77batch/s]
# Training batches on cpu:  15%|█▊          | 817/5397 [00:28<02:27, 30.98batch/s]
# Training batches on cpu:  15%|█▊          | 821/5397 [00:28<02:26, 31.16batch/s]
# Training batches on cpu:  15%|█▊          | 825/5397 [00:28<02:26, 31.18batch/s]
# Training batches on cpu:  15%|█▊          | 829/5397 [00:28<02:28, 30.75batch/s]
# Training batches on cpu:  15%|█▊          | 833/5397 [00:28<02:27, 30.95batch/s]
# Training batches on cpu:  16%|█▊          | 837/5397 [00:29<02:29, 30.50batch/s]
# Training batches on cpu:  16%|█▊          | 841/5397 [00:29<02:31, 30.16batch/s]
# Training batches on cpu:  16%|█▉          | 845/5397 [00:29<02:30, 30.26batch/s]
# Training batches on cpu:  16%|█▉          | 849/5397 [00:29<02:30, 30.18batch/s]
# Training batches on cpu:  16%|█▉          | 853/5397 [00:29<02:30, 30.24batch/s]
# Training batches on cpu:  16%|█▉          | 857/5397 [00:29<02:28, 30.57batch/s]
# Training batches on cpu:  16%|█▉          | 861/5397 [00:29<02:27, 30.81batch/s]
# Training batches on cpu:  16%|█▉          | 865/5397 [00:29<02:26, 30.98batch/s]
# Training batches on cpu:  16%|█▉          | 869/5397 [00:30<02:25, 31.13batch/s]
# Training batches on cpu:  16%|█▉          | 873/5397 [00:30<02:25, 31.14batch/s]
# Training batches on cpu:  16%|█▉          | 877/5397 [00:30<02:24, 31.22batch/s]
# Training batches on cpu:  16%|█▉          | 881/5397 [00:30<02:27, 30.71batch/s]
# Training batches on cpu:  16%|█▉          | 885/5397 [00:30<02:30, 29.98batch/s]
# Training batches on cpu:  16%|█▉          | 889/5397 [00:30<02:35, 29.07batch/s]
# Training batches on cpu:  17%|█▉          | 892/5397 [00:30<02:38, 28.40batch/s]
# Training batches on cpu:  17%|█▉          | 895/5397 [00:30<02:39, 28.21batch/s]
# Training batches on cpu:  17%|█▉          | 899/5397 [00:31<02:33, 29.21batch/s]
# Training batches on cpu:  17%|██          | 903/5397 [00:31<02:30, 29.82batch/s]
# Training batches on cpu:  17%|██          | 907/5397 [00:31<02:27, 30.35batch/s]
# Training batches on cpu:  17%|██          | 911/5397 [00:31<02:25, 30.75batch/s]
# Training batches on cpu:  17%|██          | 915/5397 [00:31<02:25, 30.80batch/s]
# Training batches on cpu:  17%|██          | 919/5397 [00:31<02:24, 31.03batch/s]
# Training batches on cpu:  17%|██          | 923/5397 [00:31<02:24, 30.99batch/s]
# Training batches on cpu:  17%|██          | 927/5397 [00:32<02:25, 30.81batch/s]
# Training batches on cpu:  17%|██          | 931/5397 [00:32<02:25, 30.80batch/s]
# Training batches on cpu:  17%|██          | 935/5397 [00:32<02:26, 30.43batch/s]
# Training batches on cpu:  17%|██          | 939/5397 [00:32<02:26, 30.45batch/s]
# Training batches on cpu:  17%|██          | 943/5397 [00:32<02:24, 30.76batch/s]
# Training batches on cpu:  18%|██          | 947/5397 [00:32<02:24, 30.84batch/s]
# Training batches on cpu:  18%|██          | 951/5397 [00:32<02:27, 30.21batch/s]
# Training batches on cpu:  18%|██          | 955/5397 [00:32<02:31, 29.23batch/s]
# Training batches on cpu:  18%|██▏         | 958/5397 [00:33<02:35, 28.61batch/s]
# Training batches on cpu:  18%|██▏         | 961/5397 [00:33<02:36, 28.27batch/s]
# Training batches on cpu:  18%|██▏         | 965/5397 [00:33<02:32, 29.06batch/s]
# Training batches on cpu:  18%|██▏         | 969/5397 [00:33<02:29, 29.68batch/s]
# Training batches on cpu:  18%|██▏         | 973/5397 [00:33<02:27, 30.08batch/s]
# Training batches on cpu:  18%|██▏         | 977/5397 [00:33<02:28, 29.82batch/s]
# Training batches on cpu:  18%|██▏         | 980/5397 [00:33<02:34, 28.65batch/s]
# Training batches on cpu:  18%|██▏         | 984/5397 [00:33<02:30, 29.39batch/s]
# Training batches on cpu:  18%|██▏         | 987/5397 [00:34<02:30, 29.40batch/s]
# Training batches on cpu:  18%|██▏         | 990/5397 [00:34<02:29, 29.51batch/s]
# Training batches on cpu:  18%|██▏         | 994/5397 [00:34<02:25, 30.19batch/s]
# Training batches on cpu:  18%|██▏         | 998/5397 [00:34<02:23, 30.62batch/s]
# Training batches on cpu:  19%|██         | 1002/5397 [00:34<02:22, 30.84batch/s]
# Training batches on cpu:  19%|██         | 1006/5397 [00:34<02:27, 29.78batch/s]
# Training batches on cpu:  19%|██         | 1009/5397 [00:34<02:27, 29.81batch/s]
# Training batches on cpu:  19%|██         | 1013/5397 [00:34<02:25, 30.21batch/s]
# Training batches on cpu:  19%|██         | 1017/5397 [00:35<02:23, 30.48batch/s]
# Training batches on cpu:  21%|██▎        | 1157/5397 [00:39<02:17, 30.92batch/s]
# Training batches on cpu:  22%|██▎        | 1161/5397 [00:39<02:18, 30.59batch/s]
# Training batches on cpu:  22%|██▎        | 1165/5397 [00:39<02:17, 30.69batch/s]
# Training batches on cpu:  22%|██▍        | 1169/5397 [00:40<04:28, 15.76batch/s]
# Training batches on cpu:  22%|██▍        | 1172/5397 [00:40<04:31, 15.54batch/s]
# Training batches on cpu:  22%|██▍        | 1175/5397 [00:40<03:58, 17.73batch/s]
# Training batches on cpu:  22%|██▍        | 1178/5397 [00:40<04:05, 17.18batch/s]
# Training batches on cpu:  22%|██▍        | 1181/5397 [00:40<03:36, 19.46batch/s]
# Training batches on cpu:  22%|██▍        | 1185/5397 [00:41<03:07, 22.42batch/s]
# Training batches on cpu:  22%|██▍        | 1189/5397 [00:41<02:50, 24.69batch/s]
# Training batches on cpu:  22%|██▍        | 1193/5397 [00:41<02:39, 26.41batch/s]
# Training batches on cpu:  22%|██▍        | 1197/5397 [00:41<02:31, 27.68batch/s]
# Training batches on cpu:  22%|██▍        | 1201/5397 [00:41<02:26, 28.71batch/s]
# Training batches on cpu:  22%|██▍        | 1205/5397 [00:41<02:23, 29.31batch/s]
# Training batches on cpu:  22%|██▍        | 1209/5397 [00:41<02:21, 29.50batch/s]
# Training batches on cpu:  22%|██▍        | 1213/5397 [00:42<02:19, 29.96batch/s]
# Training batches on cpu:  23%|██▍        | 1217/5397 [00:42<02:18, 30.09batch/s]
# Training batches on cpu:  23%|██▍        | 1221/5397 [00:42<02:19, 30.03batch/s]
# Training batches on cpu:  23%|██▍        | 1225/5397 [00:42<02:18, 30.18batch/s]
# Training batches on cpu:  23%|██▌        | 1229/5397 [00:42<02:17, 30.21batch/s]
# Training batches on cpu:  23%|██▌        | 1233/5397 [00:42<02:20, 29.69batch/s]
# Training batches on cpu:  23%|██▌        | 1237/5397 [00:42<02:17, 30.27batch/s]
# Training batches on cpu:  23%|██▌        | 1241/5397 [00:42<02:16, 30.48batch/s]
# Training batches on cpu:  23%|██▌        | 1245/5397 [00:43<02:14, 30.83batch/s]
# Training batches on cpu:  23%|██▌        | 1249/5397 [00:43<02:14, 30.73batch/s]
# Training batches on cpu:  23%|██▌        | 1253/5397 [00:43<02:16, 30.42batch/s]
# Training batches on cpu:  23%|██▌        | 1257/5397 [00:43<02:16, 30.34batch/s]
# Training batches on cpu:  23%|██▌        | 1261/5397 [00:43<02:18, 29.93batch/s]
# Training batches on cpu:  23%|██▌        | 1265/5397 [00:43<02:16, 30.21batch/s]
# Training batches on cpu:  24%|██▌        | 1269/5397 [00:43<02:15, 30.52batch/s]
# Training batches on cpu:  24%|██▌        | 1273/5397 [00:43<02:17, 30.04batch/s]
# Training batches on cpu:  24%|██▌        | 1277/5397 [00:44<02:16, 30.17batch/s]
# Training batches on cpu:  24%|██▌        | 1281/5397 [00:44<02:15, 30.48batch/s]
# Training batches on cpu:  24%|██▌        | 1285/5397 [00:44<02:13, 30.77batch/s]
# Training batches on cpu:  24%|██▋        | 1289/5397 [00:44<02:12, 30.92batch/s]
# Training batches on cpu:  24%|██▋        | 1293/5397 [00:44<02:13, 30.73batch/s]
# Training batches on cpu:  24%|██▋        | 1297/5397 [00:44<02:18, 29.63batch/s]
# Training batches on cpu:  24%|██▋        | 1301/5397 [00:44<02:17, 29.90batch/s]
# Training batches on cpu:  24%|██▋        | 1304/5397 [00:45<02:17, 29.76batch/s]
# Training batches on cpu:  24%|██▋        | 1308/5397 [00:45<02:15, 30.07batch/s]
# Training batches on cpu:  24%|██▋        | 1312/5397 [00:45<02:17, 29.77batch/s]
# Training batches on cpu:  24%|██▋        | 1316/5397 [00:45<02:15, 30.10batch/s]
# Training batches on cpu:  24%|██▋        | 1320/5397 [00:45<02:13, 30.44batch/s]
# Training batches on cpu:  25%|██▋        | 1324/5397 [00:45<02:12, 30.73batch/s]
# Training batches on cpu:  25%|██▋        | 1328/5397 [00:45<02:11, 30.94batch/s]
# Training batches on cpu:  25%|██▋        | 1332/5397 [00:45<02:12, 30.71batch/s]
# Training batches on cpu:  25%|██▋        | 1336/5397 [00:46<02:13, 30.43batch/s]
# Training batches on cpu:  25%|██▋        | 1340/5397 [00:46<02:13, 30.33batch/s]
# Training batches on cpu:  25%|██▋        | 1344/5397 [00:46<02:17, 29.37batch/s]
# Training batches on cpu:  25%|██▋        | 1347/5397 [00:46<02:18, 29.34batch/s]
# Training batches on cpu:  25%|██▊        | 1350/5397 [00:46<02:18, 29.30batch/s]
# Training batches on cpu:  25%|██▊        | 1353/5397 [00:46<02:21, 28.66batch/s]
# Training batches on cpu:  25%|██▊        | 1357/5397 [00:46<02:16, 29.53batch/s]
# Training batches on cpu:  25%|██▊        | 1361/5397 [00:46<02:13, 30.12batch/s]
# Training batches on cpu:  25%|██▊        | 1365/5397 [00:47<02:12, 30.49batch/s]
# Training batches on cpu:  25%|██▊        | 1369/5397 [00:47<02:12, 30.46batch/s]
# Training batches on cpu:  25%|██▊        | 1373/5397 [00:47<02:11, 30.50batch/s]
# Training batches on cpu:  26%|██▊        | 1377/5397 [00:47<02:11, 30.64batch/s]
# Training batches on cpu:  26%|██▊        | 1381/5397 [00:47<02:13, 30.03batch/s]
# Training batches on cpu:  26%|██▊        | 1385/5397 [00:47<02:12, 30.35batch/s]
# Training batches on cpu:  26%|██▊        | 1389/5397 [00:47<02:11, 30.43batch/s]
# Training batches on cpu:  26%|██▊        | 1393/5397 [00:47<02:11, 30.34batch/s]
# Training batches on cpu:  26%|██▊        | 1397/5397 [00:48<02:11, 30.52batch/s]
# Training batches on cpu:  26%|██▊        | 1401/5397 [00:48<02:10, 30.56batch/s]
# Training batches on cpu:  26%|██▊        | 1405/5397 [00:48<02:10, 30.66batch/s]
# Training batches on cpu:  26%|██▊        | 1409/5397 [00:48<02:09, 30.84batch/s]
# Training batches on cpu:  26%|██▉        | 1413/5397 [00:48<02:08, 30.90batch/s]
# Training batches on cpu:  26%|██▉        | 1417/5397 [00:48<02:08, 30.95batch/s]
# Training batches on cpu:  26%|██▉        | 1421/5397 [00:48<02:09, 30.77batch/s]
# Training batches on cpu:  29%|███▏       | 1555/5397 [00:53<02:21, 27.18batch/s]
# Training batches on cpu:  29%|███▏       | 1558/5397 [00:53<02:22, 26.99batch/s]
# Training batches on cpu:  29%|███▏       | 1561/5397 [00:53<02:21, 27.04batch/s]
# Training batches on cpu:  29%|███▏       | 1564/5397 [00:53<02:21, 27.05batch/s]
# Training batches on cpu:  29%|███▏       | 1567/5397 [00:53<02:18, 27.74batch/s]
# Training batches on cpu:  29%|███▏       | 1570/5397 [00:54<02:29, 25.63batch/s]
# Training batches on cpu:  29%|███▏       | 1573/5397 [00:54<02:52, 22.13batch/s]
# Training batches on cpu:  29%|███▏       | 1576/5397 [00:54<02:44, 23.28batch/s]
# Training batches on cpu:  29%|███▏       | 1579/5397 [00:54<02:41, 23.68batch/s]
# Training batches on cpu:  29%|███▏       | 1582/5397 [00:54<02:38, 24.12batch/s]
# Training batches on cpu:  29%|███▏       | 1585/5397 [00:54<02:44, 23.17batch/s]
# Training batches on cpu:  29%|███▏       | 1588/5397 [00:54<03:01, 20.93batch/s]
# Training batches on cpu:  29%|███▏       | 1591/5397 [00:55<03:03, 20.80batch/s]
# Training batches on cpu:  30%|███▏       | 1594/5397 [00:55<02:51, 22.22batch/s]
# Training batches on cpu:  30%|███▎       | 1597/5397 [00:55<05:36, 11.28batch/s]
# Training batches on cpu:  30%|███▎       | 1599/5397 [00:55<05:25, 11.67batch/s]
# Training batches on cpu:  30%|███▎       | 1602/5397 [00:55<04:40, 13.55batch/s]
# Training batches on cpu:  30%|███▎       | 1605/5397 [00:56<03:56, 16.02batch/s]
# Training batches on cpu:  30%|███▎       | 1608/5397 [00:56<04:00, 15.73batch/s]
# Training batches on cpu:  30%|███▎       | 1611/5397 [00:56<03:28, 18.19batch/s]
# Training batches on cpu:  30%|███▎       | 1614/5397 [00:56<03:04, 20.46batch/s]
# Training batches on cpu:  30%|███▎       | 1617/5397 [00:56<02:48, 22.39batch/s]
# Training batches on cpu:  30%|███▎       | 1620/5397 [00:56<02:37, 23.93batch/s]
# Training batches on cpu:  30%|███▎       | 1623/5397 [00:56<02:55, 21.47batch/s]
# Training batches on cpu:  30%|███▎       | 1626/5397 [00:57<02:52, 21.88batch/s]
# Training batches on cpu:  30%|███▎       | 1629/5397 [00:57<02:50, 22.13batch/s]
# Training batches on cpu:  30%|███▎       | 1632/5397 [00:57<02:45, 22.71batch/s]
# Training batches on cpu:  30%|███▎       | 1635/5397 [00:57<02:39, 23.59batch/s]
# Training batches on cpu:  30%|███▎       | 1638/5397 [00:57<02:36, 24.09batch/s]
# Training batches on cpu:  30%|███▎       | 1641/5397 [00:57<02:30, 24.93batch/s]
# Training batches on cpu:  30%|███▎       | 1644/5397 [00:57<02:24, 26.05batch/s]
# Training batches on cpu:  31%|███▎       | 1647/5397 [00:57<02:24, 26.00batch/s]
# Training batches on cpu:  31%|███▎       | 1650/5397 [00:57<02:21, 26.43batch/s]
# Training batches on cpu:  31%|███▎       | 1653/5397 [00:58<02:24, 25.84batch/s]
# Training batches on cpu:  31%|███▍       | 1656/5397 [00:58<02:25, 25.79batch/s]
# Training batches on cpu:  89%|█████████▋ | 4780/5397 [02:51<00:23, 25.98batch/s]
# Training batches on cpu:  89%|█████████▋ | 4783/5397 [02:51<00:23, 26.16batch/s]
# Training batches on cpu:  89%|█████████▊ | 4786/5397 [02:51<00:23, 25.57batch/s]
# Training batches on cpu:  89%|█████████▊ | 4789/5397 [02:51<00:23, 25.62batch/s]
# Training batches on cpu:  89%|█████████▊ | 4792/5397 [02:51<00:23, 26.16batch/s]
# Training batches on cpu:  89%|█████████▊ | 4795/5397 [02:51<00:23, 25.57batch/s]
# Training batches on cpu:  89%|█████████▊ | 4798/5397 [02:51<00:23, 25.98batch/s]
# Training batches on cpu:  89%|█████████▊ | 4801/5397 [02:51<00:22, 26.64batch/s]
# Training batches on cpu:  89%|█████████▊ | 4804/5397 [02:51<00:22, 26.72batch/s]
# Training batches on cpu:  89%|█████████▊ | 4807/5397 [02:52<00:21, 27.24batch/s]
# Training batches on cpu:  89%|█████████▊ | 4810/5397 [02:52<00:21, 27.65batch/s]
# Training batches on cpu:  89%|█████████▊ | 4813/5397 [02:52<00:20, 27.85batch/s]
# Training batches on cpu:  89%|█████████▊ | 4816/5397 [02:52<00:20, 28.15batch/s]
# Training batches on cpu:  89%|█████████▊ | 4819/5397 [02:52<00:20, 27.87batch/s]
# Training batches on cpu:  89%|█████████▊ | 4822/5397 [02:52<00:20, 27.83batch/s]
# Training batches on cpu:  89%|█████████▊ | 4825/5397 [02:52<00:20, 28.02batch/s]
# Training batches on cpu:  89%|█████████▊ | 4828/5397 [02:52<00:21, 26.78batch/s]
# Training batches on cpu:  90%|█████████▊ | 4831/5397 [02:52<00:20, 27.23batch/s]
# Training batches on cpu:  90%|█████████▊ | 4834/5397 [02:53<00:20, 27.75batch/s]
# Training batches on cpu:  90%|█████████▊ | 4837/5397 [02:53<00:20, 27.89batch/s]
# Training batches on cpu:  90%|█████████▊ | 4840/5397 [02:53<00:20, 27.38batch/s]
# Training batches on cpu:  90%|█████████▊ | 4843/5397 [02:53<00:20, 27.46batch/s]
# Training batches on cpu:  90%|█████████▉ | 4846/5397 [02:53<00:20, 27.42batch/s]
# Training batches on cpu:  90%|█████████▉ | 4849/5397 [02:53<00:19, 27.90batch/s]
# Training batches on cpu:  90%|█████████▉ | 4852/5397 [02:53<00:19, 28.36batch/s]
# Training batches on cpu:  90%|█████████▉ | 4855/5397 [02:53<00:18, 28.79batch/s]
# Training batches on cpu:  90%|█████████▉ | 4858/5397 [02:53<00:18, 29.06batch/s]
# Training batches on cpu:  90%|█████████▉ | 4862/5397 [02:54<00:18, 29.58batch/s]
# Training batches on cpu:  90%|█████████▉ | 4865/5397 [02:54<00:18, 29.55batch/s]
# Training batches on cpu:  90%|█████████▉ | 4868/5397 [02:54<00:17, 29.61batch/s]
# Training batches on cpu:  90%|█████████▉ | 4871/5397 [02:54<00:17, 29.29batch/s]
# Training batches on cpu:  90%|█████████▉ | 4874/5397 [02:54<00:17, 29.37batch/s]
# Training batches on cpu:  90%|█████████▉ | 4878/5397 [02:54<00:17, 29.99batch/s]
# Training batches on cpu:  99%|██████████▉| 5355/5397 [03:11<00:01, 30.37batch/s]
# Training batches on cpu:  99%|██████████▉| 5359/5397 [03:11<00:01, 30.60batch/s]
# Training batches on cpu:  99%|██████████▉| 5363/5397 [03:11<00:01, 30.79batch/s]
# Training batches on cpu:  99%|██████████▉| 5367/5397 [03:11<00:00, 30.64batch/s]
# Training batches on cpu: 100%|██████████▉| 5371/5397 [03:11<00:00, 30.42batch/s]
# Training batches on cpu: 100%|██████████▉| 5375/5397 [03:11<00:00, 30.50batch/s]
# Training batches on cpu: 100%|██████████▉| 5379/5397 [03:12<00:00, 30.14batch/s]
# Training batches on cpu: 100%|██████████▉| 5383/5397 [03:12<00:00, 30.37batch/s]
# Training batches on cpu: 100%|██████████▉| 5387/5397 [03:12<00:00, 30.37batch/s]
# Training batches on cpu: 100%|██████████▉| 5391/5397 [03:12<00:00, 30.61batch/s]
# Training batches on cpu: 100%|██████████▉| 5395/5397 [03:12<00:00, 30.76batch/s]
# Training epochs on cpu:  90%|▉| 9/10 [32:00<03:13, 193.04s/epoch, loss=0.000964,INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# INFO:pykeen.evaluation.evaluator:Evaluation took 5568.27s seconds
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 10.
# Training epochs on cpu: 100%|█| 10/10 [2:08:22<00:00, 770.26s/epoch, loss=0.0009
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|███████████████| 173k/173k [1:31:58<00:00, 31.3triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 5522.47s seconds

# %%
#Saving and Restoring Model
#PyKeen Models are torch models with utility functions on the top. 
#We can use the torch’s functionality to save and reload a model.
torch.save(result.model,'result_trained_model.pkl')
result_pykeen_model = torch.load('result_trained_model.pkl') 
print(result_pykeen_model)
# Out:
# TransR(
#   (loss): MarginRankingLoss(
#     (margin_activation): ReLU()
#   )
#   (regularizer): NoRegularizer()
#   (entity_embeddings): Embedding(
#     (_embeddings): Embedding(34764, 50)
#   )
#   (relation_embeddings): Embedding(
#     (_embeddings): Embedding(3, 30)
#   )
#   (relation_projections): Embedding(
#     (_embeddings): Embedding(3, 1500)
#   )
# )

# %%
#Print some info using the first model

tail_prediction_df = get_tail_prediction_df(result.model, 'Metronidazole', 'prescribed', triples_factory=result.training)
print(tail_prediction_df.head(5))

entity_representation_modules: List['pykeen.nn.Representation'] = result.model.entity_representations
relation_representation_modules: List['pykeen.nn.Representation'] = result.model.relation_representations
    
print(entity_representation_modules)
print(relation_representation_modules)

entity_embeddings: pk.nn.Embedding = entity_representation_modules[0]
relation_embeddings: pk.nn.Embedding = relation_representation_modules[0]
    
print(entity_embeddings)
print(relation_embeddings)

entity_embedding_tensor: torch.FloatTensor = entity_embeddings()
relation_embedding_tensor: torch.FloatTensor = relation_embeddings()
    
print(entity_embedding_tensor.size())
print(relation_embedding_tensor.size())
# Out:
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")
#        tail_id      tail_label     score  in_training
# 32857    32857   Midazolam HCl -0.973746        False
# 33047    33047              NS -0.986358        False
# 32838    32838   Metronidazole -1.000000        False
# 32603    32603    Levofloxacin -1.004324        False
# 33614    33614  Sertraline HCl -1.030376        False
# [Embedding(
#   (_embeddings): Embedding(34764, 50)
# )]
# [Embedding(
#   (_embeddings): Embedding(3, 30)
# )]
# Embedding(
#   (_embeddings): Embedding(34764, 50)
# )
# Embedding(
#   (_embeddings): Embedding(3, 30)
# )
# torch.Size([34764, 50])
# torch.Size([3, 30])

# %%
embeddings = result.model.entity_representations
embedding_representation_df = pd.DataFrame(embeddings[0](indices=ids)
                   .detach()
                   .numpy(),index=labels,columns=list(range(0, result.model.embedding_dim)))
# Out:
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")

# %%
embedding_representation_df.head(5)
# Out:
#                                     0         1         2         3   \
#                               0.179895 -0.036186  0.076087 -0.117849
#  Cabergoline     ( Dostinex)  0.105885 -0.097371 -0.129243 -0.362424
#  Zaditor Ophthalmic           0.115757 -0.130979  0.093581 -0.428041
# *NF                           0.135418 -0.157106  0.124347 -0.217165
# *NF BRINZOLAMIDE (AZOPT)      0.097526 -0.071491 -0.091796 -0.231068
#
#                                     4         5         6         7   \
#                              -0.141404 -0.012701 -0.146450  0.079093
#  Cabergoline     ( Dostinex) -0.205653 -0.002321 -0.096848  0.061834
#  Zaditor Ophthalmic          -0.150609 -0.036561 -0.267573  0.025251
# *NF                          -0.126895  0.031061 -0.127900 -0.048052
# *NF BRINZOLAMIDE (AZOPT)     -0.031711 -0.113840 -0.112762 -0.001585
#
#                                     8         9   ...        40        41  \
#                              -0.117388 -0.032856  ... -0.017042 -0.026410
#  Cabergoline     ( Dostinex)  0.026691  0.010510  ... -0.096268 -0.093686
#  Zaditor Ophthalmic          -0.025937 -0.039287  ...  0.035542  0.010743
# *NF                           0.007786 -0.042639  ... -0.134794 -0.117209
# *NF BRINZOLAMIDE (AZOPT)     -0.017508  0.097502  ... -0.045289 -0.009743
#
#                                     42        43        44        45  \
#                              -0.215346 -0.041645 -0.095902  0.319287
#  Cabergoline     ( Dostinex) -0.220600  0.010017 -0.143782  0.242684
#  Zaditor Ophthalmic          -0.157510 -0.154665 -0.228586  0.228160
# *NF                          -0.114378 -0.269141 -0.086017  0.361812
# *NF BRINZOLAMIDE (AZOPT)     -0.346999 -0.079675 -0.044807  0.225305
#
#                                     46        47        48        49
#                               0.062817  0.162924  0.214109 -0.075901
#  Cabergoline     ( Dostinex)  0.068905  0.134198  0.260570  0.093007
#  Zaditor Ophthalmic           0.059939  0.131139  0.084759  0.109328
# *NF                           0.074897  0.285787  0.037477  0.002318
# *NF BRINZOLAMIDE (AZOPT)     -0.038666  0.223736  0.248430  0.128399
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Neural Network Models

# %%
#Split the resulting Entity Embedding tensor into training and validation
train_entity_embedding_tensor, test_entity_embedding_tensor = sk.train_test_split(entity_embedding_tensor,test_size=0.30, random_state = 42)

# %% [markdown]
# ### Neural Network Model 1 - Linear Activation

# %%
#NN MODEL 1

from tensorflow.keras import datasets, layers, models

nn_model = models.Sequential()

# Apply linear activation function to input layer
nn_model.add(layers.Dense(units=50, activation='linear',input_dim=50))
nn_model.add(layers.Dense(units=50, activation='linear'))
nn_model.add(layers.Dense(units=50, activation='linear'))

# Compile the model
nn_model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

print(nn_model.summary())


#Train and evaluate model with training and testing data
nn_model_history = nn_model.fit(x=train_entity_embedding_tensor.detach().numpy(), 
                                y=train_entity_embedding_tensor.detach().numpy(),
                    epochs= 50,
                    batch_size=256,
                    shuffle=True,
                    validation_data=(test_entity_embedding_tensor.detach().numpy(),
                                    test_entity_embedding_tensor.detach().numpy()),
                    verbose= False)


#Evaluate model wiht test data
# nn_test_loss, nn_test_acc = nn_model.evaluate(test_entity_embedding_tensor.detach().numpy(), 
#                                               test_entity_embedding_tensor.detach().numpy())

print("Average Accuracy:", mean(nn_model_history.history['acc']))
print("Average Loss:", mean(nn_model_history.history['loss']))

plt.title("Model Accuracy and Loss")
plt.plot(nn_model_history.history['acc'], label='Accuracy')
plt.plot(nn_model_history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

#print("Test Accuracy:", nn_test_acc)
#print("Test Loss:",nn_test_loss )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_42 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_43 (Dense)             (None, 50)                2550
# =================================================================
# Total params: 7,650
# Trainable params: 7,650
# Non-trainable params: 0
# _________________________________________________________________
# None
# Average Accuracy: 0.9220457
# Average Loss: 0.0004871929204945849

# %% [markdown]
# ### Neural Network Model 2 - Relu Activation

# %%
#NN MODEL 2

from tensorflow.keras import datasets, layers, models

nn_model_relu = models.Sequential()

# Apply linear activation function to input layer
nn_model_relu.add(layers.Dense(units=50, activation='relu',input_dim=50))
nn_model_relu.add(layers.Dense(units=50, activation='relu'))
nn_model_relu.add(layers.Dense(units=50, activation='relu'))
# Compile the model
nn_model_relu.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

print(nn_model_relu.summary())

#Train and evaluate model with training and testing data
nn_model_relu_history = nn_model_relu.fit(x=train_entity_embedding_tensor.detach().numpy(), 
                                          y=train_entity_embedding_tensor.detach().numpy(),
                        epochs=50,
                        batch_size=256,
                        shuffle=True,
                        validation_data=(test_entity_embedding_tensor.detach().numpy(), 
                                         test_entity_embedding_tensor.detach().numpy()),
                        verbose= False)



#Evaluate model wiht test data
# nn_relu_test_loss, nn_relu_test_acc =nn_model_relu.evaluate(test_entity_embedding_tensor.detach().numpy(),  
#                                               test_entity_embedding_tensor.detach().numpy())

print("Average Accuracy:", mean(nn_model_relu_history.history['acc']))
print("Average Loss:", mean(nn_model_relu_history.history['loss']))

plt.title("Accuracy and Loss")
plt.plot(nn_model_relu_history.history['acc'], label='Accuracy')
plt.plot(nn_model_relu_history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

#print("Test Accuracy:", nn_relu_test_acc)
#print("Test Loss:",nn_relu_test_loss )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_36 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_37 (Dense)             (None, 50)                2550
# =================================================================
# Total params: 7,650
# Trainable params: 7,650
# Non-trainable params: 0
# _________________________________________________________________
# None
# Average Accuracy: 0.8186603
# Average Loss: 0.011483480712115517

# %% [markdown]
# ## Convolutional Models

# %%
#Reshape Tensors
D3_train_entity_embedding_tensor = train_entity_embedding_tensor.unsqueeze(-1)
D3_test_entity_embedding_tensor = test_entity_embedding_tensor.unsqueeze(-1)

# %%
#CNN MODEL 4

from tensorflow.keras import datasets, layers, models

nn_model_relu = models.Sequential()

# Apply linear activation function to input layer
nn_model_relu.add(layers.Conv1D(250, (1), input_shape=(50,1), activation='relu'))
nn_model_relu.add(layers.Dense(units=50, activation='relu',input_dim=50))
nn_model_relu.add(layers.Dense(units=50, activation='relu'))
nn_model_relu.add(layers.Dense(units=50, activation='relu'))
# Compile the model
nn_model_relu.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

print(nn_model_relu.summary())

#Train and evaluate model with training and testing data
nn_model_relu_history = nn_model_relu.fit(x=D3_train_entity_embedding_tensor.detach().numpy(), 
                                          y=D3_train_entity_embedding_tensor.detach().numpy(),
                        epochs=100,
                        batch_size=256,
                        shuffle=True,
                        validation_data=(D3_test_entity_embedding_tensor.detach().numpy(), 
                                         D3_test_entity_embedding_tensor.detach().numpy()),
                        verbose= False)



#Evaluate model wiht test data
# nn_relu_test_loss, nn_relu_test_acc =nn_model_relu.evaluate(test_entity_embedding_tensor.detach().numpy(),  
#                                               test_entity_embedding_tensor.detach().numpy())

print("Average Accuracy:", mean(nn_model_relu_history.history['acc']))
print("Average Loss:", mean(nn_model_relu_history.history['loss']))

plt.title("Accuracy and Loss")
plt.plot(nn_model_relu_history.history['acc'], label='Accuracy')
plt.plot(nn_model_relu_history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

#print("Test Accuracy:", nn_relu_test_acc)
#print("Test Loss:",nn_relu_test_loss )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 50, 250)           500
# _________________________________________________________________
# dense_63 (Dense)             (None, 50, 50)            12550
# _________________________________________________________________
# dense_64 (Dense)             (None, 50, 50)            2550
# _________________________________________________________________
# dense_65 (Dense)             (None, 50, 50)            2550
# =================================================================
# Total params: 18,150
# Trainable params: 18,150
# Non-trainable params: 0
# _________________________________________________________________
# None
# Average Accuracy: 0.53762144
# Average Loss: 0.012797779690720287

# %% [markdown]
# ## END TEST

# %% [markdown]
# ### MODEL 2

# %%
#  MEDICAL KNOWLEDGE GRAPH EMBEDDINGS USING PYKEEN'S TRANSR METHOD 2 USING PIPELINE
#THIS MODELS USES 2 EMBEDDING DIMENSIONS AS OUTPUT

results2 = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model = 'TransR',mode
    model_kwargs=dict(embedding_dim=2),
    optimizer_kwargs=dict(lr=1.0e-1),
    training_kwargs=dict(num_epochs=10, use_tqdm_batch=False),
    random_seed=1,
    device='cpu',
)
# Out:
# INFO:pykeen.pipeline.api:Using device: cpu
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:369: UserWarning: Directly use Embedding.max_id instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.max_id instead of num_embeddings.")
# Training epochs on cpu: 100%|█| 2/2 [00:00<00:00,  3.80epoch/s, loss=0.00208, pr
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|██████████████| 1.27k/1.27k [00:00<00:00, 1.38ktriple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.95s seconds

# %%
#Saving and Restoring Model
#PyKeen Models are torch models with utility functions on the top. 
#We can use the torch’s functionality to save and reload a model.
torch.save(results2.model,'results2_trained_model.pkl')
results2_pykeen_model = torch.load('results2_trained_model.pkl') 
print(results2_pykeen_model)
# Out:
# TransR(
#   (loss): MarginRankingLoss(
#     (margin_activation): ReLU()
#   )
#   (regularizer): NoRegularizer()
#   (entity_embeddings): Embedding(
#     (_embeddings): Embedding(928, 2)
#   )
#   (relation_embeddings): Embedding(
#     (_embeddings): Embedding(3, 30)
#   )
#   (relation_projections): Embedding(
#     (_embeddings): Embedding(3, 60)
#   )
# )

# %%
#Print some info using the second model
tail_prediction_df2 = get_tail_prediction_df(results2.model, 'Metronidazole', 'prescribed', triples_factory=results2.training)
print(tail_prediction_df2.head(5))

entity_representation_modules2: List['pykeen.nn.Representation'] = results2.model.entity_representations
relation_representation_modules2: List['pykeen.nn.Representation'] = results2.model.relation_representations
    
print(entity_representation_modules2)
print(relation_representation_modules2)

entity_embeddings2: pk.nn.Embedding = entity_representation_modules2[0]
relation_embeddings2: pk.nn.Embedding = relation_representation_modules2[0]
    
print(entity_embeddings2)
print(relation_embeddings2)

entity_embedding_tensor2: torch.FloatTensor = entity_embeddings2()
relation_embedding_tensor2: torch.FloatTensor = relation_embeddings2()
    
print(entity_embedding_tensor2)
print(relation_embedding_tensor2)

print(entity_embedding_tensor2.shape)
print(relation_embedding_tensor2.shape)
# Out:
#      tail_id        tail_label     score  in_training
# 627      627      Epoetin Alfa -0.499411        False
# 630      630      Erythromycin -0.500140        False
# 844      844  Promethazine HCl -0.505781        False
# 599      599     Dexamethasone -0.506753        False
# 635      635   Famotidine (IV) -0.507375        False
# [Embedding(
#   (_embeddings): Embedding(928, 2)
# )]
# [Embedding(
#   (_embeddings): Embedding(3, 30)
# )]
# Embedding(
#   (_embeddings): Embedding(928, 2)
# )
# Embedding(
#   (_embeddings): Embedding(3, 30)
# )
# tensor([[ 0.5875,  0.8093],
#         [-0.8937,  0.2061],
#         [ 0.8751,  0.0209],
#         ...,
#         [-0.5625,  0.3090],
#         [ 0.5673,  0.1297],
#         [-0.0554, -0.9985]], grad_fn=<ViewBackward0>)
# tensor([[ 0.2716, -0.0909,  0.2029,  0.0140, -0.0839, -0.1546, -0.0946,  0.1104,
#           0.1841, -0.2262, -0.2233, -0.0906, -0.1970,  0.0608, -0.2062, -0.1136,
#          -0.2351,  0.2381,  0.1590,  0.2739,  0.1528, -0.1790,  0.2487, -0.2943,
#           0.2205,  0.0065, -0.1923, -0.1499, -0.2180,  0.1078],
#         [ 0.2533,  0.2543, -0.1147, -0.2566, -0.2716, -0.0193,  0.0057, -0.1475,
#          -0.1196, -0.1335,  0.0828, -0.1957, -0.0156,  0.1780,  0.0321, -0.2565,
#          -0.2184, -0.1331,  0.1586,  0.1509, -0.2674, -0.0733,  0.2479, -0.2005,
#          -0.1384,  0.2477,  0.1857, -0.2650, -0.0854, -0.1889],
#         [ 0.2025, -0.2507,  0.1147,  0.2534, -0.2543,  0.2029,  0.0030, -0.1613,
#          -0.2421, -0.0743, -0.1866, -0.0017,  0.1759,  0.1625, -0.1363,  0.1804,
#           0.1347, -0.2217, -0.2496,  0.2339,  0.1538,  0.2104,  0.2163,  0.2232,
#          -0.1784,  0.0738,  0.1608,  0.1915, -0.0029,  0.1758]],
#        grad_fn=<ViewBackward0>)
# torch.Size([928, 2])
# torch.Size([3, 30])

# %%
entity_representation = results2.model.entity_representations[0]
print(entity_representation)
# Out:
# Embedding(
#   (_embeddings): Embedding(928, 2)
# )

# %%
embeddings2 = results2.model.entity_representations
embedding_representation_df2 = pd.DataFrame(embeddings2[0](indices=ids)
                   .detach()
                   .numpy(),index=labels,columns=list(range(0, results2.model.embedding_dim)))

embedding_representation_df2.head()
# Out:
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")
#                                              0         1
# *NF* Nicardipine HCl IV               0.587454  0.809257
# 0.45% Sodium Chloride                -0.893690  0.206063
# 0.9% Sodium Chloride                  0.875134  0.020876
# 0.9% Sodium Chloride (Mini Bag Plus)  0.798634 -0.601817
# 00845                                -0.091921  0.995766

# %% [markdown]
# ### 3) MEDICAL ENTITY DESCRIPTION RETRIEVAL

# %%
# #For patient entity descriptions,we use the discharge summary associated with each patient from MIMIC-III
# MIMIC_Discharge_Summary = Note_Events[Note_Events['CATEGORY'] == 'Discharge summary']
# MIMIC_Discharge_Summary = MIMIC_Discharge_Summary[['SUBJECT_ID','TEXT']]
# MIMIC_Discharge_Summary = MIMIC_Discharge_Summary.dropna(subset = ['TEXT'])
# MIMIC_Discharge_Summary = MIMIC_Discharge_Summary.drop_duplicates()

# %%
# pd.set_option('display.max_colwidth', None)
# display(MIMIC_Discharge_Summary.head(5))

# %% [markdown]
# ### C. PATIENT SIMILARITY LEARNING

# %%
#embedding_values = _model_to_numpy(best_model)

#embedding_values = result.model.entity_embeddings.weight.detach().cpu().numpy()
result.model.relation_dim
# Out:
# /opt/anaconda3/envs/cse6250OlderPython/lib/python3.7/site-packages/pykeen/nn/representation.py:375: UserWarning: Directly use Embedding.shape instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.shape instead of num_embeddings.")
# 30

# %%
from ampligraph.datasets import load_fb15k_237
from ampligraph.evaluation import train_test_split_no_unseen, evaluate_performance, mr_score, mrr_score, hits_at_n_score
from ampligraph.discovery import query_topn, discover_facts, find_clusters
from ampligraph.latent_features import TransE, ComplEx, HolE, DistMult, ConvE, ConvKB
from ampligraph.utils import save_model, restore_model

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 1.13.2

# %%
# display(Medical_Knowledge_Triplets_df.head(5))
# Medical_Knowledge_Triplets_df_tmp = Medical_Knowledge_Triplets_df[Medical_Knowledge_Triplets_df.Head != "None"]
# test_train, X_valid = train_test_split_no_unseen(Medical_Knowledge_Triplets_df[['Head','Relation','Tail']].values, 500, seed=0) 

# X_train, X_test = train_test_split_no_unseen(test_train, 1000, seed=0)
# Out:
#          Head    Relation                Tail
# 476459   1000  prescribed      Vancomycin HCl
# 342817   1000   diagnosed                5789
# 1470362  1000  prescribed  D5W (GLASS BOTTLE)
# 540740   1000  prescribed        Pantoprazole
# 344206   1000   diagnosed                0380

# %%
display(Medical_Knowledge_Triplets_df.head(5))
Medical_Knowledge_Triplets_df_tmp = Medical_Knowledge_Triplets_df[Medical_Knowledge_Triplets_df.Head != "None"]
test_train, X_valid = train_test_split_no_unseen(Medical_Knowledge_Triplets_df[['Head','Relation','Tail']].values, seed=0) 

X_train, X_test = train_test_split_no_unseen(test_train, seed=0)
# Out:
#          Head    Relation                Tail
# 476459   1000  prescribed      Vancomycin HCl
# 342817   1000   diagnosed                5789
# 1470362  1000  prescribed  D5W (GLASS BOTTLE)
# 540740   1000  prescribed        Pantoprazole
# 344206   1000   diagnosed                0380

# %%
model = TransE(k=150,                                                             # embedding size
               epochs=100,                                                        # Num of epochs
               batches_count= 10,                                                 # Number of batches 
               eta=1,                                                             # number of corruptions to generate during training
               loss='pairwise', loss_params={'margin': 1},                        # loss type and it's hyperparameters         
               initializer='xavier', initializer_params={'uniform': False},       # initializer type and it's hyperparameters
               regularizer='LP', regularizer_params= {'lambda': 0.001, 'p': 3},   # regularizer along with its hyperparameters
               optimizer= 'adam', optimizer_params= {'lr': 0.001},                # optimizer to use along with its hyperparameters
               seed= 0, verbose=True)

model.fit(X_train)

from ampligraph.utils import save_model, restore_model
save_model(model, 'TransE.pkl')
model = restore_model('TransE.pkl')
# Out:
# Average TransE Loss:   0.094193: 100%|█████| 100/100 [11:02<00:00,  6.63s/epoch]

# %%
from ampligraph.discovery import find_clusters
from sklearn.cluster import KMeans

# restore the previously saved model to save time
model = restore_model('TransE.pkl')

# Get the entities that we want to cluster. Here we use all unique entities
all_entities = np.array(list(set(Medical_Knowledge_Triplets_df.values[:, 0]).union(Medical_Knowledge_Triplets_df.values[:, 2])))
print('Size of the subset being used for subset generation:', len(all_entities))

# create the clustering algorithm from sklearn
kmeans = KMeans(n_clusters=3, n_init=100, max_iter=500)

# call find_clusters to get the cluster assignments of the entities
clusters = find_clusters(all_entities, model, kmeans, mode='entity')
# Out:
# Size of the subset being used for subset generation: 34764

# %%
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# Get the embeddings (150 dims) for all the entities of interest
jobs_embeddings = model.get_embeddings(all_entities, embedding_type='entity')

# Perform PCA and reduce the dims to 2
embeddings_2d = PCA(n_components=2).fit_transform(np.array([emb for emb in jobs_embeddings]))

# Create a dataframe to plot the embeddings using scatterplot
df = pd.DataFrame({"entities": all_entities, "clusters": "cluster" + pd.Series(clusters).astype(str),
                    "embedding1": embeddings_2d[:, 0], "embedding2": embeddings_2d[:, 1]})

plt.figure(figsize=(20, 20))
plt.title("Cluster embeddings")

ax = sns.scatterplot(data=df, x="embedding1", y="embedding2", hue="clusters")

# Print only a few labels, to avoid clutter, using adjust_text
from adjustText import adjust_text
texts = []
for i, point in df.iterrows():
    # randomly choose a few labels to be printed
    if np.random.uniform() < 0.003:
        texts.append(plt.text(point['embedding1']+.1, point['embedding2'], str(point['entities'])))
        
adjust_text(texts)
plt.show()
